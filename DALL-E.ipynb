# %%
import openai
import urllib.request
from PIL import Image
import cv2
from matplotlib import pyplot as plt

# %%
openai.api_key = "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"

# %%
img_response = openai.Image.create(
    prompt = 'A futuristic fire phoenix in the middle of a blue ocean',
    n=1,
    size="512x512")    # 256x256, 512x512, 1024x1024

# %%
img_response
# Out:
# <OpenAIObject at 0x1d2af5ab220> JSON: {
#   "created": 1674414783,
#   "data": [
#     {
#       "url": "https://oaidalleapiprodscus.blob.core.windows.net/private/org-ZwCfdvAiEq30ryHJ2nYTwJWm/user-EHYyrTTYDyPNdCx10098zvfS/img-bO26hOxlpjkFjk603Z9gAmls.png?st=2023-01-22T18%3A13%3A03Z&se=2023-01-22T20%3A13%3A03Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-22T18%3A10%3A59Z&ske=2023-01-23T18%3A10%3A59Z&sks=b&skv=2021-08-06&sig=NCarheJ5a69WrL62cT4GnyJsiG9xJKZJO8NF%2BRyazHM%3D"
#     }
#   ]
# }

# %%
img_response['data'][0]['url']
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-ZwCfdvAiEq30ryHJ2nYTwJWm/user-EHYyrTTYDyPNdCx10098zvfS/img-bO26hOxlpjkFjk603Z9gAmls.png?st=2023-01-22T18%3A13%3A03Z&se=2023-01-22T20%3A13%3A03Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-22T18%3A10%3A59Z&ske=2023-01-23T18%3A10%3A59Z&sks=b&skv=2021-08-06&sig=NCarheJ5a69WrL62cT4GnyJsiG9xJKZJO8NF%2BRyazHM%3D'

# %%
img_url = img_response['data'][0]['url']
img_url
# Out:
# 'https://oaidalleapiprodscus.blob.core.windows.net/private/org-ZwCfdvAiEq30ryHJ2nYTwJWm/user-EHYyrTTYDyPNdCx10098zvfS/img-bO26hOxlpjkFjk603Z9gAmls.png?st=2023-01-22T18%3A13%3A03Z&se=2023-01-22T20%3A13%3A03Z&sp=r&sv=2021-08-06&sr=b&rscd=inline&rsct=image/png&skoid=6aaadede-4fb3-4698-a8f6-684d7786b067&sktid=a48cca56-e6da-484e-a814-9c849652bcb3&skt=2023-01-22T18%3A10%3A59Z&ske=2023-01-23T18%3A10%3A59Z&sks=b&skv=2021-08-06&sig=NCarheJ5a69WrL62cT4GnyJsiG9xJKZJO8NF%2BRyazHM%3D'

# %%
urllib.request.urlretrieve(img_url, 'image.png')
# Out:
# ('image.png', <http.client.HTTPMessage at 0x1d2af5d0a00>)

# %%
img = cv2.imread("image.png")
plt.imshow(img)
